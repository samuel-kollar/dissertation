# %%
import struct
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
import cv2
import pandas as pd
import csv
import os
from os import listdir
from os.path import isfile, join
from pathlib import Path

# %%
video_name = "summary_e619a81ff91bcf8ebc69d0763ab32681#201008230800.avi"
txt_name = "e619a81ff91bcf8ebc69d0763ab32681#201008230800.txt"
csv_name = "data_siteHoBiHu_camera1_201008230800.csv"
npy_name = "e619a81ff91bcf8ebc69d0763ab32681#201008230800.RESULT.npy"
yhat_name = "e619a81ff91bcf8ebc69d0763ab32681#201008230800.YHAT.npy"
frame_info_name = "frame_info_e619a81ff91bcf8ebc69d0763ab32681#201008230800.txt"

# %%
# create a dataframe from csv file
def create_frame(file):
    df = pd.read_csv(file)
    return df

# create readable structure from txt file
def create_frame_info(fi_name):
    with open(fi_name) as f:
        frame_info = f.readlines()
    return frame_info

# create a list of ids present in a readable structure
def get_ids_from_txt(frame_info):
    ids = []
    for line in frame_info:
        a, rest = line.split(",", 1)
        ids.append(int(a))
    return(ids)

# get IDs from dataframe
def get_ids_from_frame(frame):
    return frame['detection_id'].tolist()

#get set difference
def get_difference(a, b):
    return list(set(a).difference(set(b)))

def remove_rows(dframe, idlist):
    dframe = dframe.set_index("detection_id")
    dframe = dframe.drop(idlist, axis=0)
    return dframe

def clean_csv(csvfile, fifile):
    dframe = create_frame(csvfile)
    print("Created dataframe with {:d} rows.".format(dframe.shape[0]))
    frame_info = create_frame_info(fifile)
    print("Created frameinfo file with {:d} rows.".format(len(frame_info)))
    csvids = get_ids_from_frame(dframe)
    fiids = get_ids_from_txt(frame_info)
    diff = get_difference(csvids, fiids)
    final_frame = remove_rows(dframe, diff)
    print("Removed {:d} rows from dataframe. Final row count is {:d}.".format(len(diff), final_frame.shape[0]))
    return final_frame

def create_npy_array(npy_file):
    return np.load(npy_file)

# get all points from a contour and store as a list of tuples
def get_contour_points(contour):
    cont = contour[2:-1]
    tuples = cont.split(";")
    l = []
    for item in tuples:
        a, b = item.split(" ")
        l.append((int(a), int(b)))
    return l

# gets all contours form a dataframe. We can conveniently traverse this using detection id
def get_contours(dataframe):
    return dataframe[' contour']

def process_batch(csvname, finame, npyname, vname):
    a = clean_csv(csvname, finame)
    truths = np.load(npyname)
    idx = get_frames_with_fish(vname, truths, a)
    b = remove_rows_by_index(a, idx)
    print("Kept {:d} lines based on npy T/F.".format(b.shape[0]))
    videoID = a.iloc[0][' video_id'][1:]
    return b

def get_frames_with_fish(vname, npy, dframe):
    videoID = dframe.iloc[0][' video_id'][1:]
    vidcap = cv2.VideoCapture(vname)
    success,image = vidcap.read()
    count = 0
    rows_to_remove = []
    frame = 0
    while success:
        if (npy[count]):
            fid = str(list(full_df.index.values)[frame])
            imgname = "output/img/"+fid+".jpg"
#             print(imgname)
            cv2.imwrite(imgname, image)     # save frame as JPG file
#             plt.imshow(image)
#             plt.show()
            frame+= 1
        else:
            rows_to_remove.append(count)
        success,image = vidcap.read()
        count += 1
    return rows_to_remove

def remove_rows_by_index(dframe, idxlist):
    return dframe.drop(dframe.index[idxlist])
   
def get_points_from_contour(contour):
    cont = contour[2:-1]
    tuples = cont.split(";")
    final = []
    for item in tuples:
        (x, y) = item.split(" ")
        print(x,y)
        final.append([(x, y)])
    return final

def get_frame_count(video):
    vidcap = cv2.VideoCapture(video)
    success, image = vidcap.read()
    count = 0
    while success:
        success, image = vidcap.read()
        count += 1
    return count

def get_metadata(dframe):
    df = pd.DataFrame(columns=[' fish_id', ' video_id', ' bounding_box_x', ' bounding_box_y', ' specie_id', 
                               ' contour'])
    indices = dframe.index.tolist()
    for i, idx in enumerate(indices):
        row = dframe.loc[idx]
        fid = row[' fish_id']
        vid = row[' video_id']
        bbx = row[' bounding_box_x']
        bby = row[' bounding_box_y']
        sid = row[' specie_id']
        contour = row[' contour']
        df.loc[idx] = [fid, vid, bbx, bby, sid, contour]
#         print(df)
    return df

def process_image(img_name, x, y, cont_points):
    img = cv2.imread(img_name)
    mask = np.zeros((100,100))
    xdiff = x - 10
    ydiff = y - 10
    xs = []
    ys = []
    for (a,b) in cont_points:
        v = a - xdiff
        u = b - ydiff
        xs.append(u)
        ys.append(v)
        img[u,v] = (0,0,255)
        mask[u,v] = 1
    return img, mask, xs, ys

def produce_RGB_nRGB_avgs(shrunk_csv):
    indices = shrunk_csv.index.tolist()
    dframe = pd.DataFrame(columns=["B", "G", "R", "nB", "nG", "nR"])
    vname = shrunk_csv.iloc[0][' video_id'][1:]
    for idx, l in enumerate(indices):
        # create contour points
        contour = get_contour_points(shrunk_csv.loc[l][5])
        # get bb starting point
        x = shrunk_csv.loc[l][2]
        y = shrunk_csv.loc[l][3]
        # set name to pick correct image
        imgname = "output/img/"+str(l)+".jpg"
#         print(imgname)
        # process image
        img, mask, xs, ys = process_image(imgname, x, y, contour)
        # get average x and y coordinate of boundary
#         plt.imshow(img)
#         plt.show()
        imgname2 = "output/contoured/"+str(l)+".jpg"
        cv2.imwrite(imgname2, img)
        xavg = int(np.mean(xs))
        yavg = int(np.mean(ys))
        # set coordinates for CoM point
        startpoint = (xavg, yavg)
        # compute CoM-based shape
        com(img, startpoint, mask)
        # extract specific channels
        channel0 = img[:,:,0]
        channel1 = img[:,:,1]
        channel2 = img[:,:,2]
        # compute averages
        c0avg = np.mean(mask*channel0)
        c1avg = np.mean(mask*channel1)
        c2avg = np.mean(mask*channel2)
        # compute normalized image
        normRGB = normalizedRGB(img)
        # extract normalized RGB channels
        normc0 = normRGB[:,:,0]
        normc1 = normRGB[:,:,1]
        normc2 = normRGB[:,:,2]
        # compute averages
        normc0avg = np.mean(mask*normc0)
        normc1avg = np.mean(mask*normc1)
        normc2avg = np.mean(mask*normc2)
        # save to dataframe
        dframe.loc[l] = [c0avg, c1avg, c2avg, normc0avg, normc1avg, normc2avg]
        
    vid = "output/csv/"+shrunk_csv.loc[l][1] + ".csv"
    dframe.to_csv(vid)
    return dframe

def normalizedRGB(img):
    newimg=np.zeros((img.shape))
    for i, row in enumerate(img):
        for j, col in enumerate(row):
            b,g,r = col
            s = b+g+r
            newimg[i,j] = (b//s), (g//s), (r//s)
    return newimg        

def com(img, startpoint, mask):
    (xavg, yavg) = startpoint
    
    nextleft = (xavg, yavg-1)
    nextright = (xavg, yavg+1)
    nextup = (xavg+1, yavg)
    nextdown = (xavg-1, yavg)
    
    if (mask[nextleft]==0):
        mask[nextleft] = 1
        com(img, nextleft, mask)
    if (mask[nextright]==0):
        mask[nextright] = 1
        com(img, nextright, mask)
    if (mask[nextup]==0):
        mask[nextup] = 1
        com(img, nextup, mask)
    if (mask[nextdown]==0):
        mask[nextdown] = 1
        com(img, nextdown, mask)

# %%
line = csvnames[0][:-1]
print("Started processing {}.".format(line))

full_path_and_name = path_to_csvs + line

df = pd.read_csv(full_path_and_name)

videoID = df.iloc[0][4][1:]

video_name_fix = "summary_" + videoID + ".avi"
npy_name_fix = videoID + ".RESULT.npy"
frame_info_fix = "frame_info_" + videoID + ".txt"

videos_dir = "/media/sam/My Passport/FISH4KNOWLEDGE/f4k_extracted_image/output/summaries/"
frame_info_dir = "/media/sam/My Passport/FISH4KNOWLEDGE/f4k_extracted_image/output/summaries/"
npy_dir = "/media/sam/My Passport/FISH4KNOWLEDGE/final/"

video_path = find(video_name_fix, videos_dir)
frame_info_path = find(frame_info_fix, frame_info_dir)
npy_path = find(npy_name_fix, npy_dir)

# print(video_path)
# print(frame_info_path)
# print(npy_path)

full_df = process_batch(full_path_and_name, frame_info_path, npy_path, video_path)
metadata = get_metadata(full_df)
produce_RGB_nRGB_avgs(metadata)
print(videoID, " done.")
# Out:
# Started processing data_siteHoBiHu_camera1_201008230800.csv.
# Created dataframe with 21 rows.
# Created frameinfo file with 16 rows.
# Removed 5 rows from dataframe. Final row count is 16.
# Kept 3 lines based on npy T/F.
# e619a81ff91bcf8ebc69d0763ab32681#201008230800  done.
# /home/sam/anaconda3/envs/mlp/lib/python3.7/site-packages/ipykernel_launcher.py:203: RuntimeWarning: overflow encountered in ubyte_scalars
# /home/sam/anaconda3/envs/mlp/lib/python3.7/site-packages/ipykernel_launcher.py:204: RuntimeWarning: divide by zero encountered in ubyte_scalars

# %%
metadata
# Out:
#             fish_id                                        video_id  \
# 432533639  38529590   e619a81ff91bcf8ebc69d0763ab32681#201008230800
# 432533642  38529590   e619a81ff91bcf8ebc69d0763ab32681#201008230800
# 432533647  38529590   e619a81ff91bcf8ebc69d0763ab32681#201008230800
#
#            bounding_box_x  bounding_box_y  specie_id  \
# 432533639              91             108          0
# 432533642             123              88          0
# 432533647             256              27          0
#
#                                                      contour
# 432533639   [123 108;124 108;125 108;126 108;127 108;128 ...
# 432533642   [177 88;178 88;179 88;180 88;181 88;182 88;18...
# 432533647   [259 27;260 27;261 27;262 27;263 27;264 27;26...

# %%
def find(name, path):
    for root, dirs, files in os.walk(path):
        if name in files:
            return os.path.join(root, name)

# %%
path_to_csvs = "/media/sam/Sam\'s Drive/SUBSET/SQL/ALLYEARS/"
mypath = "/media/sam/Sam\'s Drive/SUBSET/SQL/ALLYEARS"

# csvnames = [f for f in listdir(mypath) if isfile(join(mypath, f))]

# %%
donecount = 0
for i, name in enumerate(csvnames):
    try:
        full_path_and_name = path_to_csvs + name
        df = pd.read_csv(full_path_and_name)
        videoID = df.iloc[0][4][1:]
        video_name_fix = "summary_" + videoID + ".avi"
        npy_name_fix = videoID + ".RESULT.npy"
        frame_info_fix = "frame_info_" + videoID + ".txt"
        videos_dir = "/media/sam/My Passport/FISH4KNOWLEDGE/f4k_extracted_image/output/summaries/"
        frame_info_dir = "/media/sam/My Passport/FISH4KNOWLEDGE/f4k_extracted_image/output/summaries/"
        npy_dir = "/media/sam/My Passport/FISH4KNOWLEDGE/final/"
        video_path = find(video_name_fix, videos_dir)
        frame_info_path = find(frame_info_fix, frame_info_dir)
        npy_path = find(npy_name_fix, npy_dir)
        full_df = process_batch(full_path_and_name, frame_info_path, npy_path, video_path)
        metadata = get_metadata(full_df)
        produce_RGB_nRGB_avgs(metadata)
        donecount += 1
        diff = (i+1-donecount)
        # delete frames
        for p in Path(".").glob("frame*.jpg"):
            p.unlink()
        print(videoID, " done. So far skipped ", diff, " videos.")
    except TypeError:
        continue
    except IndexError:
# Out:
#   File "<ipython-input-14-2cc0db956700>", line 28
#
#     ^
# SyntaxError: unexpected EOF while parsing

# %%
with open('csvnames.txt', 'r') as f:
    csvnames = f.readlines()

# %%
asd = np.load(npy_path)

# %%
print(frame_info_path)
# Out:
# None

# %%
# to clean the names when we don't have the files
for i, name in enumerate(csvnames):
    full_path_and_name = path_to_csvs + name
    df = pd.read_csv(full_path_and_name)
    videoID = df.iloc[0][4][1:]
    video_name_fix = "summary_" + videoID + ".avi"
    npy_name_fix = videoID + ".RESULT.npy"
    frame_info_fix = "frame_info_" + videoID + ".txt"
    videos_dir = "/media/sam/My Passport/FISH4KNOWLEDGE/f4k_extracted_image/output/summaries/"
    frame_info_dir = "/media/sam/My Passport/FISH4KNOWLEDGE/f4k_extracted_image/output/summaries/"
    npy_dir = "/media/sam/My Passport/FISH4KNOWLEDGE/final/"
    video_path = find(video_name_fix, videos_dir)
    frame_info_path = find(frame_info_fix, frame_info_dir)
    npy_path = find(npy_name_fix, npy_dir)
    if (npy_path==None):
        print("Removed {:s} from list.".format(name))
        csvnames.remove(name)
    elif (video_path==None):
        print("Removed {:s} from list.".format(name))
        csvnames.remove(name)
    elif (frame_info_path==None):
        print("Removed {:s} from list.".format(name))
        csvnames.remove(name)
    if (i % 10 == 0):
        print("{:d} items done.".format(i))
# Out:
# 0 items done.
# 10 items done.
# Removed data_siteNPP-3_camera1_201203280800.csv from list.
# Removed data_siteNPP-3_camera1_201203300800.csv from list.
# Removed data_siteNPP-3_camera1_201204010800.csv from list.
# Removed data_siteNPP-3_camera1_201204030800.csv from list.
# Removed data_siteNPP-3_camera1_201204050800.csv from list.
# Removed data_siteNPP-3_camera1_201204120800.csv from list.
# 20 items done.
# Removed data_siteNPP-3_camera1_201204200800.csv from list.
# 30 items done.
# 40 items done.
# 50 items done.
# Removed data_siteNPP-3_camera3_201006200800.csv from list.
# Removed data_siteNPP-3_camera3_201007200800.csv from list.
# Removed data_siteNPP-3_camera3_201007230800.csv from list.
# Removed data_siteNPP-3_camera3_201007260800.csv from list.
# 60 items done.
# Removed data_siteLanYu_camera1_201008060800.csv from list.
# 70 items done.
# Removed data_siteLanYu_camera1_201008080800.csv from list.
# Removed data_siteLanYu_camera1_201008160800.csv from list.
# 80 items done.
# Removed data_siteHoBiHu_camera1_201012020800.csv from list.
# 90 items done.
# Removed data_siteHoBiHu_camera1_201103160800.csv from list.
# Removed data_siteNPP-3_camera4_201106300800.csv from list.
# 100 items done.
# Removed data_siteNPP-3_camera4_201107140800.csv from list.
# 110 items done.
# Removed data_siteNPP-3_camera2_201106030800.csv from list.
# Removed data_siteNPP-3_camera2_201106050800.csv from list.
# Removed data_siteNPP-3_camera2_201106100800.csv from list.
# Removed data_siteNPP-3_camera2_201106120800.csv from list.
# Removed data_siteNPP-3_camera2_201106140800.csv from list.
# Removed data_siteNPP-3_camera2_201106160800.csv from list.
# 120 items done.
# 130 items done.
# Removed data_siteNPP-3_camera3_201108220800.csv from list.
# Removed data_siteNPP-3_camera3_201108250800.csv from list.
# 140 items done.
# Removed data_siteNPP-3_camera3_201109020800.csv from list.
# Removed data_siteNPP-3_camera2_200910040800.csv from list.
# 150 items done.
# Removed data_siteNPP-3_camera2_200910130800.csv from list.
# 160 items done.
# Removed data_siteNPP-3_camera1_201102080800.csv from list.
# 170 items done.
# Removed data_siteNPP-3_camera1_201102230800.csv from list.
# 180 items done.
# Removed data_siteHoBiHu_camera2_201102030800.csv from list.
# Removed data_siteHoBiHu_camera2_201102100800.csv from list.
# 190 items done.
# Removed data_siteNPP-3_camera4_201006080800.csv from list.
# Removed data_siteNPP-3_camera4_201006150800.csv from list.
# 200 items done.
# Removed data_siteNPP-3_camera4_201211080800.csv from list.
# 210 items done.
# Removed data_siteNPP-3_camera4_201211140800.csv from list.
# Removed data_siteNPP-3_camera4_201211220800.csv from list.
# 220 items done.
# Removed data_siteNPP-3_camera4_201211260800.csv from list.
# 230 items done.
# Removed data_siteNPP-3_camera2_201211060800.csv from list.
# 240 items done.
# Removed data_siteNPP-3_camera2_201211190800.csv from list.
# Removed data_siteNPP-3_camera2_201211220800.csv from list.
# 250 items done.
# Removed data_siteNPP-3_camera2_201011150800.csv from list.
# Removed data_siteNPP-3_camera2_201011180800.csv from list.
# 260 items done.
# Removed data_siteNPP-3_camera1_201107280800.csv from list.
# Removed data_siteNPP-3_camera1_201107300800.csv from list.
# Removed data_siteNPP-3_camera1_201108020800.csv from list.
# 270 items done.
# 280 items done.
# Removed data_siteHoBiHu_camera1_201102170800.csv from list.
# Removed data_siteLanYu_camera2_201104300800.csv from list.
# 290 items done.
# Removed data_siteLanYu_camera2_201105090800.csv from list.
# 300 items done.
# Removed data_siteNPP-3_camera2_201201230800.csv from list.
# 310 items done.
# Removed data_siteNPP-3_camera2_201201260800.csv from list.
# Removed data_siteNPP-3_camera2_201201280800.csv from list.
# Removed data_siteNPP-3_camera2_201202040800.csv from list.
# Removed data_siteNPP-3_camera2_201202060800.csv from list.
# 320 items done.
# 330 items done.
# Removed data_siteHoBiHu_camera3_201101230800.csv from list.
# Removed data_siteHoBiHu_camera3_201101260800.csv from list.
# Removed data_siteNPP-3_camera3_201104280800.csv from list.
# 340 items done.
# Removed data_siteNPP-3_camera3_201104300800.csv from list.
# Removed data_siteNPP-3_camera3_201105060800.csv from list.
# 350 items done.
# Removed data_siteNPP-3_camera3_201105200800.csv from list.
# Removed data_siteNPP-3_camera3_201105220800.csv from list.
# 360 items done.
# 370 items done.
# Removed data_siteNPP-3_camera2_201011250800.csv from list.
# Removed data_siteNPP-3_camera2_201102080800.csv from list.
# Removed data_siteNPP-3_camera2_201103150800.csv from list.
# Removed data_siteNPP-3_camera2_201104210800.csv from list.
# 380 items done.
# Removed data_siteNPP-3_camera2_201106230800.csv from list.
# Removed data_siteNPP-3_camera3_201305150800.csv from list.
# Removed data_siteNPP-3_camera3_201306020800.csv from list.
# Removed data_siteNPP-3_camera3_201306040800.csv from list.
# Removed data_siteNPP-3_camera3_201306070800.csv from list.
# 390 items done.
# Removed data_siteNPP-3_camera3_201306090800.csv from list.
# 400 items done.
# Removed data_siteLanYu_camera1_201104010800.csv from list.
# 410 items done.
# Removed data_siteLanYu_camera1_201104100800.csv from list.
# Removed data_siteNPP-3_camera3_201204270800.csv from list.
# Removed data_siteNPP-3_camera3_201204290800.csv from list.
# 420 items done.
# Removed data_siteNPP-3_camera2_201304180800.csv from list.
# Removed data_siteNPP-3_camera2_201304210800.csv from list.
# Removed data_siteNPP-3_camera2_201304230800.csv from list.
# 430 items done.
# Removed data_siteNPP-3_camera2_201304250800.csv from list.
# Removed data_siteNPP-3_camera2_201304280800.csv from list.
# Removed data_siteNPP-3_camera2_201304300800.csv from list.
# Removed data_siteNPP-3_camera2_201305020800.csv from list.
# Removed data_siteNPP-3_camera1_201008010800.csv from list.
# 440 items done.
# Removed data_siteNPP-3_camera1_201008080800.csv from list.
# Removed data_siteNPP-3_camera1_201008100800.csv from list.
# 450 items done.
# Removed data_siteNPP-3_camera4_201101090800.csv from list.
# 460 items done.
# 470 items done.
# Removed data_siteNPP-3_camera2_201004030800.csv from list.
# Removed data_siteNPP-3_camera2_201004140800.csv from list.
# 480 items done.
# 490 items done.
# Removed data_siteNPP-3_camera2_201103160800.csv from list.
# 500 items done.
# Removed data_siteNPP-3_camera2_201103200800.csv from list.
# Removed data_siteNPP-3_camera2_201103230800.csv from list.
# Removed data_siteNPP-3_camera2_201103250800.csv from list.
# 510 items done.
# Removed data_siteNPP-3_camera1_201302030800.csv from list.
# 520 items done.
# Removed data_siteNPP-3_camera1_201302060800.csv from list.
# Removed data_siteNPP-3_camera1_201302120800.csv from list.
# 530 items done.
# Removed data_siteNPP-3_camera1_201302190800.csv from list.
# Removed data_siteNPP-3_camera2_201109090800.csv from list.
# Removed data_siteNPP-3_camera2_201109120800.csv from list.
# 540 items done.
# Removed data_siteNPP-3_camera2_201109190800.csv from list.
# Removed data_siteHoBiHu_camera2_201010020800.csv from list.
# 550 items done.
# Removed data_siteHoBiHu_camera2_201010150800.csv from list.
# 560 items done.
# Removed data_siteNPP-3_camera3_201101150800.csv from list.
# Removed data_siteNPP-3_camera3_201111300800.csv from list.
# Removed data_siteNPP-3_camera3_201112020800.csv from list.
# 570 items done.
# Removed data_siteNPP-3_camera3_201112060800.csv from list.
# Removed data_siteNPP-3_camera3_201112160800.csv from list.
# 580 items done.
# Removed data_siteNPP-3_camera2_201301270800.csv from list.
# Removed data_siteNPP-3_camera2_201301290800.csv from list.
# Removed data_siteNPP-3_camera2_201302010800.csv from list.
# 590 items done.
# Removed data_siteNPP-3_camera2_201205250800.csv from list.
# Removed data_siteNPP-3_camera2_201205270800.csv from list.
# 600 items done.
# Removed data_siteNPP-3_camera2_201205300800.csv from list.
# Removed data_siteNPP-3_camera2_201206010800.csv from list.
# 610 items done.
# Removed data_siteNPP-3_camera2_201206120800.csv from list.
# Removed data_siteLanYu_camera1_201003260800.csv from list.
# 620 items done.
# Removed data_siteLanYu_camera1_201003300800.csv from list.
# 630 items done.
# Removed data_siteLanYu_camera1_201004170800.csv from list.
# Removed data_siteNPP-3_camera3_201302050800.csv from list.
# Removed data_siteNPP-3_camera3_201302070800.csv from list.
# Removed data_siteNPP-3_camera3_201302110800.csv from list.
# 640 items done.
# Removed data_siteNPP-3_camera3_201302170800.csv from list.
# Removed data_siteNPP-3_camera3_201302190800.csv from list.
# 650 items done.
# Removed data_siteNPP-3_camera4_201302150800.csv from list.
# 660 items done.
# Removed data_siteNPP-3_camera4_201302220800.csv from list.
# Removed data_siteNPP-3_camera3_201110150800.csv from list.
# Removed data_siteNPP-3_camera3_201202280800.csv from list.
# 670 items done.
# Removed data_siteNPP-3_camera1_201112080800.csv from list.
# 680 items done.
# Removed data_siteNPP-3_camera1_201112140800.csv from list.
# 690 items done.
# Removed data_siteNPP-3_camera1_201105290800.csv from list.
# 700 items done.
# 710 items done.
# Removed data_siteLanYu_camera1_201010180800.csv from list.
# 720 items done.
# Removed data_siteLanYu_camera1_201010230800.csv from list.
# 730 items done.
# Removed data_siteNPP-3_camera4_201103310800.csv from list.
# 740 items done.
# Removed data_siteNPP-3_camera4_201104030800.csv from list.
# 750 items done.
# Removed data_siteNPP-3_camera1_200912310800.csv from list.
# 760 items done.
# Removed data_siteNPP-3_camera1_201001130800.csv from list.
# Removed data_siteNPP-3_camera1_201206300800.csv from list.
# Removed data_siteNPP-3_camera1_201207020800.csv from list.
# 770 items done.
# Removed data_siteNPP-3_camera1_201207040800.csv from list.
# Removed data_siteNPP-3_camera1_201207080800.csv from list.
# Removed data_siteNPP-3_camera1_201207100800.csv from list.
# Removed data_siteNPP-3_camera1_201207130800.csv from list.
# Removed data_siteNPP-3_camera1_200910290800.csv from list.
# 780 items done.
# Removed data_siteNPP-3_camera1_201006110800.csv from list.
# 790 items done.
# 800 items done.
# Removed data_siteLanYu_camera2_201102190800.csv from list.
# 810 items done.
# 820 items done.
# Removed data_siteNPP-3_camera3_201107160800.csv from list.
# 830 items done.
# Removed data_siteNPP-3_camera3_201107190800.csv from list.
# Removed data_siteNPP-3_camera4_201108280800.csv from list.
# Removed data_siteNPP-3_camera4_201109120800.csv from list.
# 840 items done.
# Removed data_siteLanYu_camera1_201108170800.csv from list.
# Removed data_siteLanYu_camera1_201108210800.csv from list.
# 850 items done.
# Removed data_siteLanYu_camera2_201108010800.csv from list.
# Removed data_siteLanYu_camera2_201108060800.csv from list.
# 860 items done.
# Removed data_siteLanYu_camera2_201108100800.csv from list.
# Removed data_siteLanYu_camera2_201108120800.csv from list.
# Removed data_siteLanYu_camera2_201108140800.csv from list.
# Removed data_siteLanYu_camera2_201108200800.csv from list.
# 870 items done.
# Removed data_siteNPP-3_camera4_201009240800.csv from list.
# 880 items done.
# Removed data_siteNPP-3_camera4_201010010800.csv from list.
# 890 items done.
# Removed data_siteHoBiHu_camera3_201011290800.csv from list.
# 900 items done.
# Removed data_siteHoBiHu_camera2_201104050800.csv from list.
# 910 items done.
# Removed data_siteHoBiHu_camera1_201011250800.csv from list.
# 920 items done.
# Removed data_siteNPP-3_camera3_201207270800.csv from list.
# 930 items done.
# Removed data_siteNPP-3_camera3_201103200800.csv from list.
# Removed data_siteNPP-3_camera3_201103240800.csv from list.
# 940 items done.
# Removed data_siteNPP-3_camera3_201103290800.csv from list.
# 950 items done.
# Removed data_siteNPP-3_camera4_201002110800.csv from list.
# 960 items done.
# 970 items done.
# Removed data_siteHoBiHu_camera3_201104090800.csv from list.
# 980 items done.
# Removed data_siteHoBiHu_camera3_201104230800.csv from list.
# 990 items done.
# Removed data_siteNPP-3_camera2_201008070800.csv from list.
# Removed data_siteNPP-3_camera2_201008090800.csv from list.
# Removed data_siteNPP-3_camera2_201008110800.csv from list.
# 1000 items done.
# Removed data_siteNPP-3_camera2_201209090800.csv from list.
# Removed data_siteNPP-3_camera2_201209130800.csv from list.
# Removed data_siteNPP-3_camera2_201209180800.csv from list.
# 1010 items done.
# Removed data_siteNPP-3_camera2_201107180800.csv from list.
# Removed data_siteNPP-3_camera2_201107280800.csv from list.
# 1020 items done.
# 1030 items done.
# Removed data_siteNPP-3_camera4_201209140800.csv from list.
# Removed data_siteNPP-3_camera4_201209170800.csv from list.
# Removed data_siteNPP-3_camera4_201209220800.csv from list.
# 1040 items done.
# Removed data_siteNPP-3_camera4_201209280800.csv from list.
# Removed data_siteNPP-3_camera3_201004140800.csv from list.
# 1050 items done.
# 1060 items done.
# 1070 items done.
# Removed data_siteNPP-3_camera4_201204280800.csv from list.
# 1080 items done.
# Removed data_siteNPP-3_camera1_201304130800.csv from list.
# 1090 items done.
# Removed data_siteLanYu_camera1_201101060800.csv from list.
# Removed data_siteLanYu_camera1_201101100800.csv from list.
# Removed data_siteLanYu_camera1_201101120800.csv from list.
# Removed data_siteLanYu_camera1_201101140800.csv from list.
# 1100 items done.
# Removed data_siteLanYu_camera1_201101170800.csv from list.
# Removed data_siteLanYu_camera1_201101190800.csv from list.
# Removed data_siteHoBiHu_camera1_201104080800.csv from list.
# Removed data_siteHoBiHu_camera1_201104120800.csv from list.
# 1110 items done.
# Removed data_siteHoBiHu_camera1_201104140800.csv from list.
# Removed data_siteHoBiHu_camera1_201104160800.csv from list.
# Removed data_siteHoBiHu_camera1_201104200800.csv from list.
# Removed data_siteLanYu_camera1_201005270800.csv from list.
# Removed data_siteLanYu_camera1_201006010800.csv from list.
# 1120 items done.
# Removed data_siteNPP-3_camera3_201202020800.csv from list.
# 1130 items done.
# Removed data_siteNPP-3_camera3_201202090800.csv from list.
# 1140 items done.
# Removed data_siteNPP-3_camera2_201101300800.csv from list.
# 1150 items done.
# Removed data_siteNPP-3_camera4_201303260800.csv from list.
# Removed data_siteNPP-3_camera4_201303300800.csv from list.
# 1160 items done.
# Removed data_siteNPP-3_camera4_201304040800.csv from list.
# Removed data_siteNPP-3_camera1_201110020800.csv from list.
# Removed data_siteNPP-3_camera1_201110080800.csv from list.
# 1170 items done.
# Removed data_siteNPP-3_camera2_201203300800.csv from list.
# Removed data_siteNPP-3_camera2_201204010800.csv from list.
# 1180 items done.
# Removed data_siteNPP-3_camera2_201204030800.csv from list.
# Removed data_siteNPP-3_camera2_201204050800.csv from list.
# Removed data_siteNPP-3_camera2_201204090800.csv from list.
# Removed data_siteNPP-3_camera2_201204120800.csv from list.
# Removed data_siteNPP-3_camera2_201204140800.csv from list.
# Removed data_siteNPP-3_camera4_201105070800.csv from list.
# Removed data_siteNPP-3_camera4_201105140800.csv from list.
# 1190 items done.
# Removed data_siteNPP-3_camera4_201105210800.csv from list.
# Removed data_siteNPP-3_camera4_201105250800.csv from list.
# 1200 items done.
# Removed data_siteHoBiHu_camera2_201012010800.csv from list.
# Removed data_siteHoBiHu_camera2_201012050800.csv from list.
# 1210 items done.
# Removed data_siteNPP-3_camera2_201110140800.csv from list.
# Removed data_siteNPP-3_camera2_201110200800.csv from list.
# 1220 items done.
# Removed data_siteNPP-3_camera3_201009080800.csv from list.
# 1230 items done.
# Removed data_siteNPP-3_camera3_201009130800.csv from list.
# Removed data_siteNPP-3_camera3_201009220800.csv from list.
# 1240 items done.
# Removed data_siteNPP-3_camera3_201304130800.csv from list.
# 1250 items done.
# Removed data_siteNPP-3_camera3_201304150800.csv from list.
# Removed data_siteNPP-3_camera3_201304200800.csv from list.
# Removed data_siteNPP-3_camera3_201304220800.csv from list.
# 1260 items done.
# 1270 items done.
# Removed data_siteNPP-3_camera1_201212140800.csv from list.
# Removed data_siteNPP-3_camera1_201212160800.csv from list.
# Removed data_siteNPP-3_camera3_201110010800.csv from list.
# 1280 items done.
# Removed data_siteNPP-3_camera3_201110130800.csv from list.
# 1290 items done.
# Removed data_siteNPP-3_camera4_201105060800.csv from list.
# Removed data_siteNPP-3_camera4_201109190800.csv from list.
# 1300 items done.
# Removed data_siteNPP-3_camera4_201110150800.csv from list.
# Removed data_siteNPP-3_camera4_201110220800.csv from list.
# 1310 items done.
# Removed data_siteNPP-3_camera4_201111210800.csv from list.
# 1320 items done.
# Removed data_siteNPP-3_camera1_201106240800.csv from list.
# 1330 items done.
# Removed data_siteNPP-3_camera1_201107030800.csv from list.
# Removed data_siteNPP-3_camera3_201206100800.csv from list.
# Removed data_siteNPP-3_camera3_201206140800.csv from list.
# 1340 items done.
# Removed data_siteNPP-3_camera3_201206180800.csv from list.
# Removed data_siteNPP-3_camera3_201206240800.csv from list.
# Removed data_siteNPP-3_camera3_201206270800.csv from list.
# 1350 items done.
# Removed data_siteNPP-3_camera3_201206300800.csv from list.
# Removed data_siteNPP-3_camera2_201212220800.csv from list.
# Removed data_siteNPP-3_camera2_201301020800.csv from list.
# 1360 items done.
# 1370 items done.
# Removed data_siteNPP-3_camera1_201104180800.csv from list.
# 1380 items done.
# Removed data_siteNPP-3_camera2_201105070800.csv from list.
# 1390 items done.
# Removed data_siteNPP-3_camera1_201205240800.csv from list.
# Removed data_siteNPP-3_camera1_201205260800.csv from list.
# Removed data_siteNPP-3_camera1_201205310800.csv from list.
# Removed data_siteNPP-3_camera1_201206020800.csv from list.
# Removed data_siteNPP-3_camera1_201206070800.csv from list.
# Removed data_siteNPP-3_camera3_201212040800.csv from list.
# 1400 items done.
# Removed data_siteNPP-3_camera3_201212060800.csv from list.
# Removed data_siteNPP-3_camera3_201212080800.csv from list.
# Removed data_siteNPP-3_camera3_201212100800.csv from list.
# Removed data_siteNPP-3_camera3_201212120800.csv from list.
# Removed data_siteNPP-3_camera3_201212150800.csv from list.
# Removed data_siteNPP-3_camera3_201212170800.csv from list.
# Removed data_siteNPP-3_camera3_201212190800.csv from list.
# 1410 items done.
# Removed data_siteNPP-3_camera3_201102130800.csv from list.
# 1420 items done.
# Removed data_siteNPP-3_camera2_201211230800.csv from list.
# Removed data_siteNPP-3_camera2_201303090800.csv from list.
# Removed data_siteNPP-3_camera2_201305070800.csv from list.
# 1430 items done.
# Removed data_siteHoBiHu_camera1_201104230800.csv from list.
# 1440 items done.
# Removed data_siteLanYu_camera1_201107160800.csv from list.
# Removed data_siteNPP-3_camera1_201111290800.csv from list.
# Removed data_siteNPP-3_camera3_201108180800.csv from list.
# 1450 items done.
# 1460 items done.
# Removed data_siteHoBiHu_camera3_201103110800.csv from list.
# Removed data_siteLanYu_camera1_201004180800.csv from list.
# 1470 items done.
# Removed data_siteLanYu_camera1_201010300800.csv from list.
# 1480 items done.
# Removed data_siteLanYu_camera1_201101040800.csv from list.
# 1490 items done.
# Removed data_siteNPP-3_camera4_201102210800.csv from list.
# Removed data_siteNPP-3_camera4_201102280800.csv from list.
# 1500 items done.
# Removed data_siteNPP-3_camera3_201106180800.csv from list.
# 1510 items done.
# Removed data_siteNPP-3_camera3_201107010800.csv from list.
# 1520 items done.
# Removed data_siteLanYu_camera1_201104300800.csv from list.
# Removed data_siteLanYu_camera1_201105030800.csv from list.
# Removed data_siteLanYu_camera1_201105080800.csv from list.
# Removed data_siteLanYu_camera1_201105130800.csv from list.
# 1530 items done.
# Removed data_siteLanYu_camera1_201106010800.csv from list.
# 1540 items done.
# Removed data_siteNPP-3_camera4_201107270800.csv from list.
# 1550 items done.
# 1560 items done.
# Removed data_siteNPP-3_camera2_201001280800.csv from list.
# Removed data_siteNPP-3_camera2_201002040800.csv from list.
# 1570 items done.
# Removed data_siteNPP-3_camera2_201002080800.csv from list.
# Removed data_siteLanYu_camera2_201012210800.csv from list.
# 1580 items done.
# Removed data_siteLanYu_camera2_201012230800.csv from list.
# 1590 items done.
# 1600 items done.
# Removed data_siteNPP-3_camera4_201004100800.csv from list.
# 1610 items done.
# Removed data_siteNPP-3_camera4_201004150800.csv from list.
# Removed data_siteLanYu_camera2_201103250800.csv from list.
# 1620 items done.
# 1630 items done.
# Removed data_siteHoBiHu_camera3_201105170800.csv from list.
# Removed data_siteHoBiHu_camera3_201105190800.csv from list.
# Removed data_siteNPP-3_camera1_201006060800.csv from list.
# Removed data_siteNPP-3_camera1_201006080800.csv from list.
# 1640 items done.
# Removed data_siteNPP-3_camera1_201006100800.csv from list.
# Removed data_siteLanYu_camera1_201009160800.csv from list.
# 1650 items done.
# Removed data_siteNPP-3_camera1_201009230800.csv from list.
# 1660 items done.
# Removed data_siteNPP-3_camera1_201009280800.csv from list.
# 1670 items done.
# Removed data_siteNPP-3_camera1_201203260800.csv from list.
# Removed data_siteNPP-3_camera1_201208110800.csv from list.
# 1680 items done.
# Removed data_siteNPP-3_camera1_201201280800.csv from list.
# Removed data_siteNPP-3_camera1_201201300800.csv from list.
# 1690 items done.
# 1700 items done.
# Removed data_siteNPP-3_camera2_201005120800.csv from list.
# Removed data_siteNPP-3_camera2_201005200800.csv from list.
# 1710 items done.
# Removed data_siteNPP-3_camera2_201006010800.csv from list.
# Removed data_siteNPP-3_camera2_201303100800.csv from list.
# Removed data_siteNPP-3_camera2_201303120800.csv from list.
# Removed data_siteNPP-3_camera2_201303140800.csv from list.
# Removed data_siteNPP-3_camera2_201303160800.csv from list.
# Removed data_siteNPP-3_camera2_201303180800.csv from list.
# Removed data_siteNPP-3_camera2_201303200800.csv from list.
# 1720 items done.
# Removed data_siteNPP-3_camera2_201303240800.csv from list.
# Removed data_siteNPP-3_camera2_201303260800.csv from list.
# 1730 items done.
# Removed data_siteHoBiHu_camera2_201105070800.csv from list.
# Removed data_siteHoBiHu_camera2_201105180800.csv from list.
# 1740 items done.
# Removed data_siteNPP-3_camera1_201208120800.csv from list.
# Removed data_siteNPP-3_camera1_201208140800.csv from list.
# Removed data_siteNPP-3_camera1_201208180800.csv from list.
# Removed data_siteNPP-3_camera1_201208200800.csv from list.
# 1750 items done.
# Removed data_siteNPP-3_camera4_200910150800.csv from list.
# 1760 items done.
# Removed data_siteLanYu_camera1_201011270800.csv from list.
# Removed data_siteLanYu_camera1_201011300800.csv from list.
# Removed data_siteLanYu_camera1_201012040800.csv from list.
# Removed data_siteLanYu_camera1_201012060800.csv from list.
# 1770 items done.
# Removed data_siteLanYu_camera1_201012100800.csv from list.
# Removed data_siteNPP-3_camera4_201203020800.csv from list.
# Removed data_siteNPP-3_camera4_201203040800.csv from list.
# 1780 items done.
# Removed data_siteNPP-3_camera4_201203140800.csv from list.
# 1790 items done.
# 1800 items done.
# Removed data_siteNPP-3_camera4_201212160800.csv from list.
# Removed data_siteNPP-3_camera4_201212180800.csv from list.
# Removed data_siteNPP-3_camera4_201212200800.csv from list.
# 1810 items done.
# Removed data_siteNPP-3_camera2_201307090800.csv from list.
# 1820 items done.
# Removed data_siteNPP-3_camera3_200910060800.csv from list.
# 1830 items done.
# Removed data_siteNPP-3_camera3_201104140800.csv from list.
# Removed data_siteNPP-3_camera3_201104160800.csv from list.
# 1840 items done.
# Removed data_siteNPP-3_camera3_201104210800.csv from list.
# 1850 items done.
# Removed data_siteLanYu_camera2_201109280800.csv from list.
# Removed data_siteLanYu_camera2_201110010800.csv from list.
# 1860 items done.
# 1870 items done.
# Removed data_siteHoBiHu_camera1_201101070800.csv from list.
# 1880 items done.
# Removed data_siteNPP-3_camera3_201107220800.csv from list.
# 1890 items done.
# Removed data_siteNPP-3_camera3_201107270800.csv from list.
# Removed data_siteNPP-3_camera3_201107290800.csv from list.
# Removed data_siteNPP-3_camera3_201108040800.csv from list.
# 1900 items done.
# 1910 items done.
# Removed data_siteNPP-3_camera2_201009130800.csv from list.
# Removed data_siteNPP-3_camera2_201009150800.csv from list.
# 1920 items done.
# Removed data_siteNPP-3_camera1_201108200800.csv from list.
# 1930 items done.
# Removed data_siteNPP-3_camera1_201108230800.csv from list.
# Removed data_siteNPP-3_camera1_201108260800.csv from list.
# Removed data_siteNPP-3_camera3_201202290800.csv from list.
# Removed data_siteNPP-3_camera3_201203030800.csv from list.
# 1940 items done.
# 1950 items done.
# Removed data_siteNPP-3_camera3_201203210800.csv from list.
# Removed data_siteNPP-3_camera1_201303240800.csv from list.
# 1960 items done.
# Removed data_siteNPP-3_camera1_201304030800.csv from list.
# Removed data_siteNPP-3_camera1_201304060800.csv from list.
# Removed data_siteNPP-3_camera4_201011110800.csv from list.
# 1970 items done.
# Removed data_siteNPP-3_camera4_201011250800.csv from list.
# 1980 items done.
# Removed data_siteNPP-3_camera4_201012010800.csv from list.
# Removed data_siteHoBiHu_camera2_201103060800.csv from list.
# 1990 items done.
# Removed data_siteHoBiHu_camera2_201103100800.csv from list.
# 2000 items done.
# Removed data_siteNPP-3_camera1_201003070800.csv from list.
# 2010 items done.
# Removed data_siteHoBiHu_camera2_201012310800.csv from list.
# 2020 items done.
# Removed data_siteHoBiHu_camera2_201101040800.csv from list.
# Removed data_siteNPP-3_camera2_201202240800.csv from list.
# Removed data_siteNPP-3_camera2_201202270800.csv from list.
# Removed data_siteNPP-3_camera2_201202290800.csv from list.
# 2030 items done.
# Removed data_siteNPP-3_camera2_201203020800.csv from list.
# Removed data_siteNPP-3_camera2_201203040800.csv from list.
# Removed data_siteNPP-3_camera2_201203080800.csv from list.
# 2040 items done.
# Removed data_siteNPP-3_camera4_201008240800.csv from list.
# 2050 items done.
# Removed data_siteNPP-3_camera3_201003150800.csv from list.
# Removed data_siteNPP-3_camera3_201003180800.csv from list.
# 2060 items done.
# 2070 items done.
# Removed data_siteNPP-3_camera3_201012040800.csv from list.
# 2080 items done.
# Removed data_siteNPP-3_camera2_201106240800.csv from list.
# Removed data_siteNPP-3_camera2_201106260800.csv from list.
# 2090 items done.
# Removed data_siteNPP-3_camera2_201107010800.csv from list.
# Removed data_siteNPP-3_camera2_201107030800.csv from list.
# Removed data_siteNPP-3_camera2_201107100800.csv from list.
# 2100 items done.
# Removed data_siteNPP-3_camera2_201107120800.csv from list.
# Removed data_siteNPP-3_camera2_201107140800.csv from list.
# Removed data_siteLanYu_camera1_201102160800.csv from list.
# 2110 items done.
# Removed data_siteLanYu_camera1_201102240800.csv from list.
# 2120 items done.
# Removed data_siteHoBiHu_camera3_201102030800.csv from list.
# 2130 items done.
# Removed data_siteNPP-3_camera2_201102260800.csv from list.
# Removed data_siteNPP-3_camera2_201103040800.csv from list.
# 2140 items done.
# Removed data_siteNPP-3_camera2_201103100800.csv from list.
# Removed data_siteNPP-3_camera2_201209220800.csv from list.
# 2150 items done.
# Removed data_siteNPP-3_camera2_201210050800.csv from list.
# Removed data_siteNPP-3_camera2_201210070800.csv from list.
# Removed data_siteNPP-3_camera2_201210090800.csv from list.
# 2160 items done.
# Removed data_siteNPP-3_camera4_201304250800.csv from list.
# Removed data_siteNPP-3_camera4_201304270800.csv from list.
# 2170 items done.
# Removed data_siteNPP-3_camera4_201305070800.csv from list.
# Removed data_siteNPP-3_camera4_201305110800.csv from list.
# Removed data_siteNPP-3_camera4_201207270800.csv from list.
# 2180 items done.
# Removed data_siteNPP-3_camera4_201208100800.csv from list.
# Removed data_siteNPP-3_camera4_201208140800.csv from list.
# 2190 items done.
# Removed data_siteNPP-3_camera3_201301050800.csv from list.
# Removed data_siteNPP-3_camera3_201301070800.csv from list.
# Removed data_siteNPP-3_camera3_201301090800.csv from list.
# Removed data_siteNPP-3_camera3_201301110800.csv from list.
# Removed data_siteNPP-3_camera3_201301150800.csv from list.
# 2200 items done.
# Removed data_siteLanYu_camera1_201006270800.csv from list.
# Removed data_siteLanYu_camera1_201006300800.csv from list.
# Removed data_siteLanYu_camera1_201007040800.csv from list.
# 2210 items done.
# Removed data_siteNPP-3_camera4_201108100800.csv from list.
# 2220 items done.
# Removed data_siteNPP-3_camera4_201108180800.csv from list.
# Removed data_siteNPP-3_camera4_201108200800.csv from list.
# 2230 items done.
# Removed data_siteNPP-3_camera2_201204220800.csv from list.
# Removed data_siteNPP-3_camera2_201204250800.csv from list.
# Removed data_siteNPP-3_camera2_201204290800.csv from list.
# Removed data_siteNPP-3_camera2_201205010800.csv from list.
# 2240 items done.
# Removed data_siteNPP-3_camera4_201106130800.csv from list.
# Removed data_siteNPP-3_camera4_201106160800.csv from list.
# Removed data_siteNPP-3_camera4_201106200800.csv from list.
# Removed data_siteNPP-3_camera4_201106230800.csv from list.
# Removed data_siteNPP-3_camera4_201106250800.csv from list.
# 2250 items done.
# Removed data_siteNPP-3_camera3_201303140800.csv from list.
# Removed data_siteNPP-3_camera3_201303180800.csv from list.
# Removed data_siteNPP-3_camera3_201303210800.csv from list.
# 2260 items done.
# Removed data_siteNPP-3_camera3_201304020800.csv from list.
# Removed data_siteNPP-3_camera3_201304040800.csv from list.
# 2270 items done.
# Removed data_siteNPP-3_camera3_201209040800.csv from list.
# 2280 items done.
# 2290 items done.
# Removed data_siteNPP-3_camera1_201211210800.csv from list.
# Removed data_siteNPP-3_camera1_201211260800.csv from list.
# 2300 items done.
# Removed data_siteNPP-3_camera2_201111290800.csv from list.
# 2310 items done.
# Removed data_siteNPP-3_camera2_201112070800.csv from list.
# 2320 items done.
# Removed data_siteNPP-3_camera4_201104290800.csv from list.
# Removed data_siteNPP-3_camera4_201105010800.csv from list.
# Removed data_siteNPP-3_camera4_201105030800.csv from list.
# 2330 items done.
# Removed data_siteNPP-3_camera4_201005140800.csv from list.
# 2340 items done.
# 2350 items done.
# Removed data_siteHoBiHu_camera3_201012060800.csv from list.
# 2360 items done.
# Removed data_siteHoBiHu_camera1_201103250800.csv from list.
# Removed data_siteHoBiHu_camera1_201103270800.csv from list.
# 2370 items done.
# Removed data_siteNPP-3_camera4_201210080800.csv from list.
# Removed data_siteNPP-3_camera4_201210140800.csv from list.
# 2380 items done.
# Removed data_siteLanYu_camera1_201004240800.csv from list.
# Removed data_siteLanYu_camera1_201004270800.csv from list.
# 2390 items done.
# Removed data_siteLanYu_camera1_201004300800.csv from list.
# 2400 items done.
# Removed data_siteHoBiHu_camera1_201009300800.csv from list.
# 2410 items done.
# Removed data_siteHoBiHu_camera3_201010240800.csv from list.
# 2420 items done.
# Removed data_siteLanYu_camera1_201001090800.csv from list.
# 2430 items done.
# Removed data_siteNPP-3_camera4_201112030800.csv from list.
# Removed data_siteNPP-3_camera4_201112100800.csv from list.
# 2440 items done.
# Removed data_siteLanYu_camera2_201105140800.csv from list.
# Removed data_siteLanYu_camera2_201105290800.csv from list.
# Removed data_siteLanYu_camera2_201107170800.csv from list.
# 2450 items done.
# Removed data_siteLanYu_camera2_201107240800.csv from list.
# Removed data_siteLanYu_camera2_201107290800.csv from list.
# Removed data_siteNPP-3_camera1_201107080800.csv from list.
# 2460 items done.
# Removed data_siteNPP-3_camera1_201107100800.csv from list.
# Removed data_siteNPP-3_camera1_201107180800.csv from list.
# 2470 items done.
# 2480 items done.
# Removed data_siteNPP-3_camera3_201210300800.csv from list.
# Removed data_siteNPP-3_camera3_201211040800.csv from list.
# Removed data_siteNPP-3_camera3_201211070800.csv from list.
# 2490 items done.
# Removed data_siteNPP-3_camera3_201211100800.csv from list.
# Removed data_siteNPP-3_camera3_201303120800.csv from list.
# Removed data_siteNPP-3_camera3_201304270800.csv from list.
# Removed data_siteNPP-3_camera3_201307050800.csv from list.
# Removed data_siteNPP-3_camera4_201002260800.csv from list.
# 2500 items done.
# Removed data_siteNPP-3_camera4_201007290800.csv from list.
# 2510 items done.
# Removed data_siteNPP-3_camera4_201001090800.csv from list.
# Removed data_siteNPP-3_camera4_201001130800.csv from list.
# 2520 items done.
# Removed data_siteNPP-3_camera4_201001250800.csv from list.
# Removed data_siteNPP-3_camera4_201001270800.csv from list.
# Removed data_siteLanYu_camera1_201107170800.csv from list.
# 2530 items done.
# Removed data_siteLanYu_camera1_201107190800.csv from list.
# Removed data_siteLanYu_camera1_201107210800.csv from list.
# Removed data_siteLanYu_camera1_201107230800.csv from list.
# Removed data_siteLanYu_camera1_201107260800.csv from list.
# Removed data_siteLanYu_camera1_201107290800.csv from list.
# 2540 items done.
# Removed data_siteNPP-3_camera1_201301120800.csv from list.
# Removed data_siteNPP-3_camera1_201301140800.csv from list.
# 2550 items done.
# 2560 items done.
# Removed data_siteNPP-3_camera4_201202100800.csv from list.
# 2570 items done.
# Removed data_siteNPP-3_camera3_201207060800.csv from list.
# Removed data_siteNPP-3_camera3_201207080800.csv from list.
# Removed data_siteNPP-3_camera3_201207100800.csv from list.
# 2580 items done.
# Removed data_siteNPP-3_camera3_201207130800.csv from list.
# Removed data_siteNPP-3_camera3_201207150800.csv from list.
# Removed data_siteNPP-3_camera3_201207170800.csv from list.
# Removed data_siteNPP-3_camera3_201207210800.csv from list.
# Removed data_siteNPP-3_camera3_201112200800.csv from list.
# 2590 items done.
# 2600 items done.
# Removed data_siteNPP-3_camera4_201003080800.csv from list.
# 2610 items done.
# Removed data_siteNPP-3_camera4_201003150800.csv from list.
# 2620 items done.
# Removed data_siteNPP-3_camera1_201008300800.csv from list.
# Removed data_siteNPP-3_camera1_201009090800.csv from list.
# 2630 items done.
# Removed data_siteNPP-3_camera1_201103040800.csv from list.
# 2640 items done.
# Removed data_siteNPP-3_camera1_201103180800.csv from list.
# 2650 items done.
# Removed data_siteNPP-3_camera2_201001010800.csv from list.
# 2660 items done.
# Removed data_siteLanYu_camera1_201109170800.csv from list.
# 2670 items done.
# Removed data_siteLanYu_camera1_201109200800.csv from list.
# 2680 items done.
# Removed data_siteLanYu_camera1_201110040800.csv from list.
# 2690 items done.
# Removed data_siteLanYu_camera2_201105130800.csv from list.
# Removed data_siteNPP-3_camera3_201105290800.csv from list.
# Removed data_siteNPP-3_camera3_201105310800.csv from list.
# 2700 items done.
# Removed data_siteNPP-3_camera3_201106120800.csv from list.
# Removed data_siteNPP-3_camera3_201106140800.csv from list.
# Removed data_siteNPP-3_camera2_201108060800.csv from list.
# Removed data_siteNPP-3_camera2_201108090800.csv from list.
# Removed data_siteNPP-3_camera2_201108110800.csv from list.
# 2710 items done.
# Removed data_siteNPP-3_camera2_201108140800.csv from list.
# Removed data_siteNPP-3_camera2_201108170800.csv from list.
# Removed data_siteNPP-3_camera2_201108190800.csv from list.
# Removed data_siteNPP-3_camera2_201108210800.csv from list.
# Removed data_siteNPP-3_camera2_201108230800.csv from list.
# Removed data_siteNPP-3_camera3_201008100800.csv from list.
# 2720 items done.
# Removed data_siteNPP-3_camera3_201008170800.csv from list.
# Removed data_siteNPP-3_camera3_201008230800.csv from list.
# 2730 items done.
# 2740 items done.
# Removed data_siteNPP-3_camera3_201001100800.csv from list.
# 2750 items done.
# Removed data_siteNPP-3_camera3_201001250800.csv from list.
# 2760 items done.
# 2770 items done.
# 2780 items done.
# Removed data_siteNPP-3_camera1_201101250800.csv from list.
# 2790 items done.
# 2800 items done.
# Removed data_siteLanYu_camera2_201104250800.csv from list.
# 2810 items done.
# Removed data_siteNPP-3_camera4_201301170800.csv from list.
# 2820 items done.
# Removed data_siteNPP-3_camera4_201301270800.csv from list.
# Removed data_siteNPP-3_camera4_201301290800.csv from list.
# Removed data_siteNPP-3_camera4_201301310800.csv from list.
# 2830 items done.
# Removed data_siteNPP-3_camera1_201110270800.csv from list.
# 2840 items done.
# 2850 items done.
# Removed data_siteNPP-3_camera4_201202080800.csv from list.
# 2860 items done.
# 2870 items done.
# Removed data_siteNPP-3_camera3_201006100800.csv from list.
# 2880 items done.
# Removed data_siteNPP-3_camera1_201104290800.csv from list.
# Removed data_siteNPP-3_camera1_201105010800.csv from list.
# 2890 items done.
# Removed data_siteNPP-3_camera1_201105070800.csv from list.
# 2900 items done.
# Removed data_siteNPP-3_camera4_201102010800.csv from list.
# 2910 items done.
# Removed data_siteNPP-3_camera4_201102120800.csv from list.
# Removed data_siteNPP-3_camera2_201211290800.csv from list.
# 2920 items done.
# Removed data_siteNPP-3_camera2_201212110800.csv from list.
# Removed data_siteNPP-3_camera2_201212140800.csv from list.
# 2930 items done.
# Removed data_siteNPP-3_camera2_201212160800.csv from list.
# 2940 items done.
# Removed data_siteNPP-3_camera3_201107210800.csv from list.
# 2950 items done.
# Removed data_siteLanYu_camera2_201012110800.csv from list.
# 2960 items done.
# Removed data_siteNPP-3_camera4_201203260800.csv from list.
# Removed data_siteNPP-3_camera4_201203280800.csv from list.
# Removed data_siteNPP-3_camera4_201203300800.csv from list.
# Removed data_siteNPP-3_camera4_201204010800.csv from list.
# Removed data_siteNPP-3_camera4_201204030800.csv from list.
# 2970 items done.
# Removed data_siteNPP-3_camera4_201204080800.csv from list.
# Removed data_siteNPP-3_camera4_201204130800.csv from list.
# Removed data_siteHoBiHu_camera1_201105030800.csv from list.
# 2980 items done.
# Removed data_siteHoBiHu_camera1_201105110800.csv from list.
# Removed data_siteNPP-3_camera3_201103010800.csv from list.
# 2990 items done.
# Removed data_siteNPP-3_camera3_201103060800.csv from list.
# Removed data_siteNPP-3_camera3_201103080800.csv from list.
# Removed data_siteNPP-3_camera3_201103100800.csv from list.
# Removed data_siteNPP-3_camera3_201103120800.csv from list.
# Removed data_siteHoBiHu_camera3_201103190800.csv from list.
# 3000 items done.
# Removed data_siteHoBiHu_camera3_201103250800.csv from list.
# Removed data_siteHoBiHu_camera3_201103280800.csv from list.
# 3010 items done.
# Removed data_siteNPP-3_camera1_201006130800.csv from list.
# Removed data_siteNPP-3_camera1_201006150800.csv from list.
# Removed data_siteNPP-3_camera1_201006180800.csv from list.
# Removed data_siteNPP-3_camera1_201007190800.csv from list.
# 3020 items done.
# Removed data_siteNPP-3_camera1_201007250800.csv from list.
# Removed data_siteNPP-3_camera1_201007270800.csv from list.
# Removed data_siteHoBiHu_camera1_201101260800.csv from list.
# 3030 items done.
# Removed data_siteHoBiHu_camera1_201102010800.csv from list.
# Removed data_siteHoBiHu_camera1_201102050800.csv from list.
# Removed data_siteHoBiHu_camera1_201102090800.csv from list.
# 3040 items done.
# 3050 items done.
# 3060 items done.
# Removed data_siteNPP-3_camera4_201103080800.csv from list.
# Removed data_siteNPP-3_camera4_201103130800.csv from list.
# 3070 items done.
# Removed data_siteNPP-3_camera4_201103180800.csv from list.
# Removed data_siteNPP-3_camera2_201206190800.csv from list.
# 3080 items done.
# Removed data_siteNPP-3_camera2_201207010800.csv from list.
# Removed data_siteNPP-3_camera2_201207030800.csv from list.
# Removed data_siteNPP-3_camera2_201207050800.csv from list.
# 3090 items done.
# Removed data_siteNPP-3_camera2_201006130800.csv from list.
# 3100 items done.
# Removed data_siteNPP-3_camera2_201006180800.csv from list.
# Removed data_siteNPP-3_camera1_201106020800.csv from list.
# 3110 items done.
# Removed data_siteNPP-3_camera1_201109270800.csv from list.
# 3120 items done.
# Removed data_siteLanYu_camera2_201101240800.csv from list.
# 3130 items done.
# Removed data_siteNPP-3_camera4_201302250800.csv from list.
# Removed data_siteNPP-3_camera4_201302270800.csv from list.
# Removed data_siteNPP-3_camera4_201303020800.csv from list.
# Removed data_siteNPP-3_camera4_201303040800.csv from list.
# Removed data_siteNPP-3_camera4_201303060800.csv from list.
# Removed data_siteNPP-3_camera4_201303080800.csv from list.
# Removed data_siteNPP-3_camera4_201303100800.csv from list.
# Removed data_siteNPP-3_camera4_201303120800.csv from list.
# 3140 items done.
# Removed data_siteNPP-3_camera4_201303150800.csv from list.
# Removed data_siteNPP-3_camera4_201303180800.csv from list.
# Removed data_siteNPP-3_camera1_201203210800.csv from list.
# 3150 items done.
# 3160 items done.
# Removed data_siteNPP-3_camera2_201009040800.csv from list.
# Removed data_siteNPP-3_camera2_201009070800.csv from list.
# Removed data_siteNPP-3_camera1_201204260800.csv from list.
# Removed data_siteNPP-3_camera1_201204290800.csv from list.
# Removed data_siteNPP-3_camera1_201205010800.csv from list.
# Removed data_siteNPP-3_camera1_201205060800.csv from list.
# Removed data_siteNPP-3_camera1_201205080800.csv from list.
# 3170 items done.
# Removed data_siteNPP-3_camera1_201205120800.csv from list.
# Removed data_siteNPP-3_camera1_201205140800.csv from list.
# Removed data_siteNPP-3_camera1_201205160800.csv from list.
# 3180 items done.
# Removed data_siteNPP-3_camera2_201006040800.csv from list.
# Removed data_siteNPP-3_camera4_201211290800.csv from list.
# 3190 items done.
# Removed data_siteNPP-3_camera4_201212050800.csv from list.
# Removed data_siteNPP-3_camera4_201212070800.csv from list.
# Removed data_siteNPP-3_camera4_201212110800.csv from list.
# Removed data_siteNPP-3_camera4_201212140800.csv from list.
# 3200 items done.
# Removed data_siteNPP-3_camera2_201003170800.csv from list.
# 3210 items done.
# Removed data_siteNPP-3_camera2_201003240800.csv from list.
# Removed data_siteHoBiHu_camera1_201012040800.csv from list.
# 3220 items done.
# Removed data_siteHoBiHu_camera1_201012080800.csv from list.
# Removed data_siteHoBiHu_camera1_201012110800.csv from list.
# Removed data_siteLanYu_camera2_201108270800.csv from list.
# 3230 items done.
# Removed data_siteLanYu_camera2_201109040800.csv from list.
# Removed data_siteLanYu_camera2_201109060800.csv from list.
# Removed data_siteLanYu_camera2_201109100800.csv from list.
# Removed data_siteLanYu_camera2_201109120800.csv from list.
# 3240 items done.
# Removed data_siteLanYu_camera1_201104170800.csv from list.
# Removed data_siteLanYu_camera1_201104200800.csv from list.
# 3250 items done.
# Removed data_siteNPP-3_camera1_201001270800.csv from list.
# 3260 items done.
# Removed data_siteNPP-3_camera1_201002010800.csv from list.
# Removed data_siteNPP-3_camera1_201002030800.csv from list.
# Removed data_siteNPP-3_camera4_201306020800.csv from list.
# 3270 items done.
# Removed data_siteNPP-3_camera4_201306130800.csv from list.
# Removed data_siteNPP-3_camera4_201307070800.csv from list.
# 3280 items done.
# 3290 items done.
# 3300 items done.
# Removed data_siteLanYu_camera2_201103100800.csv from list.
# 3310 items done.
# Removed data_siteLanYu_camera2_201103190800.csv from list.
# 3320 items done.
# 3330 items done.
# Removed data_siteNPP-3_camera3_201011140800.csv from list.
# 3340 items done.
# Removed data_siteNPP-3_camera2_201005010800.csv from list.
# Removed data_siteNPP-3_camera2_201005090800.csv from list.
# Removed data_siteNPP-3_camera2_201305080800.csv from list.
# 3350 items done.
# Removed data_siteNPP-3_camera2_201305100800.csv from list.
# Removed data_siteNPP-3_camera2_201305130800.csv from list.
# Removed data_siteNPP-3_camera2_201305160800.csv from list.
# Removed data_siteNPP-3_camera2_201306020800.csv from list.
# Removed data_siteNPP-3_camera2_201306040800.csv from list.
# Removed data_siteNPP-3_camera2_201306070800.csv from list.
# Removed data_siteNPP-3_camera2_201306100800.csv from list.
# 3360 items done.
# Removed data_siteNPP-3_camera2_201306130800.csv from list.
# Removed data_siteNPP-3_camera2_201302170800.csv from list.
# Removed data_siteNPP-3_camera2_201302220800.csv from list.
# 3370 items done.
# Removed data_siteNPP-3_camera2_201302240800.csv from list.
# Removed data_siteNPP-3_camera2_201302260800.csv from list.
# Removed data_siteNPP-3_camera2_201303010800.csv from list.
# Removed data_siteNPP-3_camera2_201303030800.csv from list.
# Removed data_siteNPP-3_camera2_201303050800.csv from list.
# Removed data_siteNPP-3_camera2_201303070800.csv from list.
# Removed data_siteLanYu_camera1_201003010800.csv from list.
# 3380 items done.
# Removed data_siteLanYu_camera1_201003110800.csv from list.
# 3390 items done.
# Removed data_siteNPP-3_camera4_201109290800.csv from list.
# Removed data_siteNPP-3_camera4_201110020800.csv from list.
# 3400 items done.
# Removed data_siteNPP-3_camera1_201209020800.csv from list.
# Removed data_siteNPP-3_camera1_201209040800.csv from list.
# Removed data_siteNPP-3_camera1_201209060800.csv from list.
# Removed data_siteNPP-3_camera1_201209080800.csv from list.
# 3410 items done.
# Removed data_siteNPP-3_camera3_201203290800.csv from list.
# Removed data_siteNPP-3_camera3_201203310800.csv from list.
# Removed data_siteNPP-3_camera3_201204020800.csv from list.
# 3420 items done.
# 3430 items done.
# Removed data_siteNPP-3_camera3_201204230800.csv from list.
# Removed data_siteNPP-3_camera3_201205150800.csv from list.
# 3440 items done.
# Removed data_siteNPP-3_camera3_201206010800.csv from list.
# 3450 items done.
# Removed data_siteHoBiHu_camera2_201010230800.csv from list.
# 3460 items done.
# Removed data_siteLanYu_camera1_201101270800.csv from list.
# Removed data_siteLanYu_camera1_201102020800.csv from list.
# 3470 items done.
# Removed data_siteLanYu_camera1_201102040800.csv from list.
# Removed data_siteLanYu_camera1_201102080800.csv from list.
# Removed data_siteLanYu_camera1_201102130800.csv from list.
# 3480 items done.
# Removed data_siteNPP-3_camera3_201012130800.csv from list.
# Removed data_siteNPP-3_camera3_201012230800.csv from list.
# 3490 items done.
# 3500 items done.
# 3510 items done.
# 3520 items done.
# Removed data_siteNPP-3_camera3_201304290800.csv from list.
# Removed data_siteNPP-3_camera3_201305010800.csv from list.
# Removed data_siteNPP-3_camera3_201305030800.csv from list.
# Removed data_siteNPP-3_camera3_201305050800.csv from list.
# Removed data_siteNPP-3_camera3_201305070800.csv from list.
# Removed data_siteNPP-3_camera3_201305090800.csv from list.
# 3530 items done.
# Removed data_siteNPP-3_camera1_201302220800.csv from list.
# Removed data_siteNPP-3_camera1_201302240800.csv from list.
# Removed data_siteNPP-3_camera1_201302260800.csv from list.
# Removed data_siteNPP-3_camera1_201303010800.csv from list.
# Removed data_siteNPP-3_camera1_201303030800.csv from list.
# Removed data_siteNPP-3_camera1_201003160800.csv from list.
# 3540 items done.
# 3550 items done.
# 3560 items done.
# 3570 items done.
# Removed data_siteHoBiHu_camera2_201009270800.csv from list.
# 3580 items done.
# Removed data_siteNPP-3_camera2_201208110800.csv from list.
# 3590 items done.
# Removed data_siteNPP-3_camera4_201012080800.csv from list.
# 3600 items done.
# Removed data_siteNPP-3_camera4_201012170800.csv from list.
# Removed data_siteNPP-3_camera4_201012300800.csv from list.
# 3610 items done.
# Removed data_siteNPP-3_camera1_201206100800.csv from list.
# 3620 items done.
# Removed data_siteNPP-3_camera1_201206240800.csv from list.
# Removed data_siteNPP-3_camera1_201206260800.csv from list.
# Removed data_siteHoBiHu_camera3_201104280800.csv from list.
# 3630 items done.
# Removed data_siteHoBiHu_camera3_201105040800.csv from list.
# 3640 items done.
# Removed data_siteNPP-3_camera1_201212280800.csv from list.
# 3650 items done.
# Removed data_siteNPP-3_camera2_201303300800.csv from list.
# Removed data_siteNPP-3_camera2_201304010800.csv from list.
# Removed data_siteNPP-3_camera2_201304030800.csv from list.
# Removed data_siteNPP-3_camera2_201304080800.csv from list.
# Removed data_siteNPP-3_camera2_201304100800.csv from list.
# Removed data_siteNPP-3_camera2_201304120800.csv from list.
# 3660 items done.
# Removed data_siteNPP-3_camera2_201105170800.csv from list.
# Removed data_siteNPP-3_camera2_201105210800.csv from list.
# Removed data_siteNPP-3_camera2_201105240800.csv from list.
# Removed data_siteNPP-3_camera2_201105260800.csv from list.
# Removed data_siteNPP-3_camera2_201105280800.csv from list.
# 3670 items done.
# Removed data_siteNPP-3_camera2_201105300800.csv from list.
# Removed data_siteNPP-3_camera2_201112100800.csv from list.
# Removed data_siteNPP-3_camera2_201202230800.csv from list.
# Removed data_siteNPP-3_camera2_201203230800.csv from list.
# Removed data_siteNPP-3_camera2_201205220800.csv from list.
# 3680 items done.
# Removed data_siteNPP-3_camera2_201209200800.csv from list.
# Removed data_siteNPP-3_camera4_201008020800.csv from list.
# 3690 items done.
# Removed data_siteNPP-3_camera4_201008070800.csv from list.
# Removed data_siteNPP-3_camera4_201008100800.csv from list.
# 3700 items done.
# Removed data_siteHoBiHu_camera3_201012240800.csv from list.
# 3710 items done.
# Removed data_siteNPP-3_camera2_201202090800.csv from list.
# Removed data_siteNPP-3_camera2_201202140800.csv from list.
# Removed data_siteNPP-3_camera2_201202170800.csv from list.
# 3720 items done.
# 3730 items done.
# Removed data_siteHoBiHu_camera3_201010160800.csv from list.
# Removed data_siteHoBiHu_camera3_201010200800.csv from list.
# Removed data_siteNPP-3_camera3_201212220800.csv from list.
# Removed data_siteNPP-3_camera3_201212240800.csv from list.
# Removed data_siteNPP-3_camera3_201212260800.csv from list.
# Removed data_siteNPP-3_camera3_201212280800.csv from list.
# Removed data_siteNPP-3_camera3_201212300800.csv from list.
# 3740 items done.
# Removed data_siteNPP-3_camera3_201301010800.csv from list.
# Removed data_siteNPP-3_camera3_201301030800.csv from list.
# Removed data_siteNPP-3_camera1_201112200800.csv from list.
# Removed data_siteNPP-3_camera1_201201200800.csv from list.
# 3750 items done.
# Removed data_siteNPP-3_camera2_201210140800.csv from list.
# Removed data_siteNPP-3_camera2_201210200800.csv from list.
# 3760 items done.
# Removed data_siteNPP-3_camera2_201102120800.csv from list.
# 3770 items done.
# Removed data_siteLanYu_camera1_201010310800.csv from list.
# Removed data_siteLanYu_camera1_201011030800.csv from list.
# 3780 items done.
# Removed data_siteLanYu_camera1_201011080800.csv from list.
# Removed data_siteLanYu_camera1_201011100800.csv from list.
# Removed data_siteLanYu_camera1_201011220800.csv from list.
# Removed data_siteLanYu_camera1_201011250800.csv from list.
# 3790 items done.
# Removed data_siteNPP-3_camera3_201110170800.csv from list.
# Removed data_siteNPP-3_camera3_201110210800.csv from list.
# Removed data_siteNPP-3_camera3_201110260800.csv from list.
# Removed data_siteNPP-3_camera3_201111250800.csv from list.
# 3800 items done.
# 3810 items done.
# Removed data_siteNPP-3_camera4_201304200800.csv from list.
# 3820 items done.
# Removed data_siteNPP-3_camera1_201210200800.csv from list.
# Removed data_siteNPP-3_camera1_201210240800.csv from list.
# Removed data_siteNPP-3_camera1_201210300800.csv from list.
# 3830 items done.
# Removed data_siteLanYu_camera1_201007140800.csv from list.
# 3840 items done.
# Removed data_siteNPP-3_camera2_201009270800.csv from list.
# Removed data_siteNPP-3_camera2_201010010800.csv from list.
# 3850 items done.
# Removed data_siteNPP-3_camera2_201010040800.csv from list.
# Removed data_siteNPP-3_camera2_201011020800.csv from list.
# 3860 items done.
# Removed data_siteNPP-3_camera2_201012010800.csv from list.
# 3870 items done.
# Removed data_siteNPP-3_camera2_201112130800.csv from list.
# 3880 items done.
# Removed data_siteNPP-3_camera2_201112190800.csv from list.
# Removed data_siteNPP-3_camera2_201201170800.csv from list.
# 3890 items done.
# Removed data_siteLanYu_camera1_201012130800.csv from list.
# Removed data_siteLanYu_camera1_201012150800.csv from list.
# 3900 items done.
# Removed data_siteLanYu_camera1_201012180800.csv from list.
# Removed data_siteLanYu_camera1_201012200800.csv from list.
# Removed data_siteLanYu_camera1_201012220800.csv from list.
# Removed data_siteLanYu_camera1_201012240800.csv from list.
# Removed data_siteLanYu_camera1_201012310800.csv from list.
# Removed data_siteLanYu_camera1_201101020800.csv from list.
# 3910 items done.
# Removed data_siteNPP-3_camera1_201207270800.csv from list.
# 3920 items done.
# Removed data_siteHoBiHu_camera1_201010120800.csv from list.
# Removed data_siteHoBiHu_camera1_201010190800.csv from list.
# 3930 items done.
# Removed data_siteHoBiHu_camera1_201010210800.csv from list.
# Removed data_siteNPP-3_camera3_200910230800.csv from list.
# 3940 items done.
# 3950 items done.
# 3960 items done.
# 3970 items done.
# Removed data_siteNPP-3_camera3_201302260800.csv from list.
# 3980 items done.
# Removed data_siteNPP-3_camera3_201303030800.csv from list.
# Removed data_siteNPP-3_camera3_201303060800.csv from list.
# Removed data_siteNPP-3_camera3_201303090800.csv from list.
# Removed data_siteNPP-3_camera4_201208240800.csv from list.
# Removed data_siteNPP-3_camera4_201209020800.csv from list.
# 3990 items done.
# Removed data_siteNPP-3_camera4_201209060800.csv from list.
# Removed data_siteNPP-3_camera4_201209100800.csv from list.
# Removed data_siteLanYu_camera1_201109060800.csv from list.
# 4000 items done.
# Removed data_siteLanYu_camera1_201109120800.csv from list.
# 4010 items done.
# Removed data_siteNPP-3_camera4_201106040800.csv from list.
# Removed data_siteNPP-3_camera1_201106040800.csv from list.
# 4020 items done.
# Removed data_siteNPP-3_camera1_201109100800.csv from list.
# 4030 items done.
# Removed data_siteNPP-3_camera1_201109160800.csv from list.
# Removed data_siteNPP-3_camera1_201109240800.csv from list.
# Removed data_siteNPP-3_camera1_201109260800.csv from list.
# 4040 items done.
# Removed data_siteNPP-3_camera3_201109150800.csv from list.
# Removed data_siteNPP-3_camera3_201109260800.csv from list.
# 4050 items done.
# Removed data_siteHoBiHu_camera2_201102180800.csv from list.
# 4060 items done.
# Removed data_siteHoBiHu_camera2_201104210800.csv from list.
# 4070 items done.
# Removed data_siteNPP-3_camera3_201307090800.csv from list.
# Removed data_siteNPP-3_camera4_200910060800.csv from list.
# 4080 items done.
# Removed data_siteLanYu_camera1_201010030800.csv from list.
# 4090 items done.
# Removed data_siteLanYu_camera1_201010050800.csv from list.
# 4100 items done.
# 4110 items done.
# Removed data_siteNPP-3_camera4_201207240800.csv from list.
# 4120 items done.
# Removed data_siteNPP-3_camera1_201304260800.csv from list.
# 4130 items done.
# 4140 items done.
# Removed data_siteNPP-3_camera3_201211250800.csv from list.
# Removed data_siteNPP-3_camera3_201211280800.csv from list.
# Removed data_siteNPP-3_camera4_201210240800.csv from list.
# Removed data_siteNPP-3_camera4_201210260800.csv from list.
# 4150 items done.
# 4160 items done.
# Removed data_siteNPP-3_camera3_201004050800.csv from list.
# 4170 items done.
# 4180 items done.
# Removed data_siteNPP-3_camera2_201205110800.csv from list.
# Removed data_siteNPP-3_camera2_201205130800.csv from list.
# Removed data_siteNPP-3_camera2_201205150800.csv from list.
# Removed data_siteNPP-3_camera2_201205180800.csv from list.
# Removed data_siteNPP-3_camera4_201301040800.csv from list.
# 4190 items done.
# Removed data_siteNPP-3_camera1_200910070800.csv from list.
# 4200 items done.
# Removed data_siteHoBiHu_camera1_201102250800.csv from list.
# 4210 items done.
# Removed data_siteLanYu_camera1_201108020800.csv from list.
# Removed data_siteLanYu_camera1_201108040800.csv from list.
# 4220 items done.
# Removed data_siteLanYu_camera1_201108110800.csv from list.
# 4230 items done.
# Removed data_siteNPP-3_camera4_201205110800.csv from list.
# Removed data_siteNPP-3_camera4_201205130800.csv from list.
# Removed data_siteNPP-3_camera4_201205150800.csv from list.
# 4240 items done.
# Removed data_siteNPP-3_camera4_201303190800.csv from list.
# Removed data_siteNPP-3_camera2_201103290800.csv from list.
# Removed data_siteNPP-3_camera2_201103310800.csv from list.
# 4250 items done.
# Removed data_siteNPP-3_camera2_201104070800.csv from list.
# Removed data_siteNPP-3_camera2_201104140800.csv from list.
# Removed data_siteNPP-3_camera2_201104160800.csv from list.
# Removed data_siteNPP-3_camera2_201104190800.csv from list.
# Removed data_siteHoBiHu_camera3_201102170800.csv from list.
# 4260 items done.
# Removed data_siteNPP-3_camera3_201208140800.csv from list.
# Removed data_siteNPP-3_camera3_201208180800.csv from list.
# 4270 items done.
# Removed data_siteNPP-3_camera3_201208200800.csv from list.
# Removed data_siteNPP-3_camera3_201208220800.csv from list.
# /home/sam/anaconda3/envs/mlp/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (2,10,13) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# Removed data_siteNPP-3_camera3_201208240800.csv from list.
# 4280 items done.
# Removed data_siteNPP-3_camera4_201206180800.csv from list.
# Removed data_siteLanYu_camera1_201005070800.csv from list.
# Removed data_siteLanYu_camera1_201005100800.csv from list.
# 4290 items done.
# Removed data_siteLanYu_camera1_201005180800.csv from list.
# Removed data_siteLanYu_camera1_201005210800.csv from list.
# 4300 items done.
# Removed data_siteNPP-3_camera2_201002240800.csv from list.
# 4310 items done.
# Removed data_siteNPP-3_camera1_201011030800.csv from list.
# 4320 items done.
# Removed data_siteNPP-3_camera1_201011110800.csv from list.
# 4330 items done.
# Removed data_siteNPP-3_camera4_201202210800.csv from list.
# Removed data_siteNPP-3_camera3_201209170800.csv from list.
# Removed data_siteNPP-3_camera3_201209190800.csv from list.
# Removed data_siteNPP-3_camera3_201209210800.csv from list.
# Removed data_siteNPP-3_camera3_201209230800.csv from list.
# 4340 items done.
# Removed data_siteNPP-3_camera1_201101020800.csv from list.
# 4350 items done.
# Removed data_siteNPP-3_camera1_201101090800.csv from list.
# 4360 items done.
# Removed data_siteNPP-3_camera1_201301270800.csv from list.
# 4370 items done.
# 4380 items done.
# Removed data_siteHoBiHu_camera2_201011040800.csv from list.
# 4390 items done.
# Removed data_siteLanYu_camera1_201006130800.csv from list.
# 4400 items done.
# Removed data_siteLanYu_camera1_201006230800.csv from list.
# Removed data_siteNPP-3_camera3_201202150800.csv from list.
# Removed data_siteNPP-3_camera3_201202180800.csv from list.
# Removed data_siteNPP-3_camera3_201202220800.csv from list.
# 4410 items done.
# Removed data_siteHoBiHu_camera2_201012110800.csv from list.
# 4420 items done.
# Removed data_siteLanYu_camera1_201110050800.csv from list.
# Removed data_siteLanYu_camera1_201110110800.csv from list.
# Removed data_siteNPP-3_camera3_201101270800.csv from list.
# 4430 items done.
# 4440 items done.
# Removed data_siteNPP-3_camera4_201009130800.csv from list.
# Removed data_siteNPP-3_camera4_201003200800.csv from list.
# 4450 items done.
# 4460 items done.
# 4470 items done.
# Removed data_siteNPP-3_camera2_201203150800.csv from list.
# Removed data_siteNPP-3_camera2_201203170800.csv from list.
# Removed data_siteNPP-3_camera2_201203190800.csv from list.
# Removed data_siteNPP-3_camera2_201203210800.csv from list.
# 4480 items done.
# Removed data_siteNPP-3_camera3_201301190800.csv from list.
# Removed data_siteNPP-3_camera3_201301210800.csv from list.
# Removed data_siteNPP-3_camera3_201301260800.csv from list.
# Removed data_siteNPP-3_camera3_201207010800.csv from list.
# 4490 items done.
# Removed data_siteNPP-3_camera3_201301040800.csv from list.
# Removed data_siteHoBiHu_camera1_201012150800.csv from list.
# Removed data_siteHoBiHu_camera1_201012170800.csv from list.
# 4500 items done.
# 4510 items done.
# 4520 items done.

# %%
# Out:
# 0

# %%
# Out:
# 4521

# %%
# Out:
# list

# %%
with open('csvnames.txt', 'w') as f:
    for item in csvnames:
        f.write("%s\n" % item)

# %%
for line in csvnames:
    full_path_and_name = path_to_csvs + line
    df = pd.read_csv(full_path_and_name)
    videoID = df.iloc[0][4][1:]
    
    video_name_fix = "summary_" + videoID + ".avi"
    npy_name_fix = videoID + ".RESULT.npy"
    frame_info_fix = "frame_info_" + videoID + ".txt"
    videos_dir = "/media/sam/My Passport/FISH4KNOWLEDGE/f4k_extracted_image/output/summaries/"
    frame_info_dir = "/media/sam/My Passport/FISH4KNOWLEDGE/f4k_extracted_image/output/summaries/"
    npy_dir = "/media/sam/My Passport/FISH4KNOWLEDGE/final/"
    video_path = find(video_name_fix, videos_dir)
    frame_info_path = find(frame_info_fix, frame_info_dir)
    npy_path = find(npy_name_fix, npy_dir)
    full_df = process_batch(full_path_and_name, frame_info_path, npy_path, video_path)
    metadata = get_metadata(full_df)
    produce_RGB_nRGB_avgs(metadata)
    # delete frames
#     for p in Path(".").glob("frame*.jpg"):
#         p.unlink()
    print(videoID, " done.")
